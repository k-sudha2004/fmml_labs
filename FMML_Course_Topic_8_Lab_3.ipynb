# %% [markdown]
# <a href="https://colab.research.google.com/github/k-sudha2004/fmml_labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 04:19:25--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   147MB/s    in 0.5s
#
# 2024-03-31 04:19:25 (147 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9880    1212.2471v1  In 1950, Forsythe and Leibler (1950) introduce...    cs
# 5339    1301.6710v1  Given a set of possible models (e.g., Bayesian...    cs
# 30713  1801.01075v1  We present the first end-to-end approach for r...    cs
# 31443  1803.04103v1  With an increased interest in applications tha...    cs
# 6003   1605.08636v4  We exhibit a strong link between frequentist P...  stat
# ...             ...                                                ...   ...
# 28912  1708.00277v3  In this work, we investigate several methods a...    cs
# 30302  1711.10792v1  In the paper, a new method of blind estimation...    cs
# 22182  1506.09068v2  Factorized Information Criterion (FIC) is a re...  stat
# 12908   1106.4333v1  Probabilistic principal component analysis (PP...  stat
# 38969  1502.00319v3  An efficient method is proposed for refining G...    cs
#
#                                                    title  year  \
# 9880      Monte Carlo Matrix Inversion Policy Evaluation  2012
# 5339        On Supervised Selection of Bayesian Networks  2013
# 30713                 Live Intrinsic Material Estimation  2018
# 31443  Full Reference Objective Quality Assessment fo...  2018
# 6003        PAC-Bayesian Theory Meets Bayesian Inference  2016
# ...                                                  ...   ...
# 28912  Learning Deep Convolutional Embeddings for Fac...  2017
# 30302  Blind estimation of white Gaussian noise varia...  2017
# 22182  On the Equivalence of Factorized Information C...  2015
# 12908                        Residual Component Analysis  2011
# 38969  Efficient refinement of GPS-based localization...  2015
#
#                                                 keywords
# 9880   [introduced, statistical, technique, character...
# 5339   [unsupervised, selection, probability, distrib...
# 30713  [estimation, lambertian, properties, automatic...
# 31443  [increased, applications, background, surveill...
# 6003   [frequentist, likelihood, likelihood, minimiza...
# ...                                                  ...
# 28912  [investigate, strategies, embeddings, recognit...
# 30302  [estimation, transform, performed, coefficient...
# 22182  [factorized, information, criterion, developed...
# 12908  [probabilistic, principal, component, dimensio...
# 38969  [efficient, coordinates, parameters, compensat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9880     [introduced, statistical, technique, character...
# 5339     [unsupervised, selection, probability, distrib...
# 30713    [estimation, lambertian, properties, automatic...
# 31443    [increased, applications, background, surveill...
# 6003     [frequentist, likelihood, likelihood, minimiza...
#                                ...
# 9734     [vulnerable, carefully, adversarial, algorithm...
# 28712    [effective, recommendation, customers, recomme...
# 36089    [potential, investigated, frequency, coefficie...
# 32783    [complimentary, objective, recurrent, regulari...
# 32111    [algorithms, discriminant, different, distance...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8951 words.
# Out of those 4595 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8d69f2ca-c50e-4d2e-afcc-89d512f5e94f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d69f2ca-c50e-4d2e-afcc-89d512f5e94f")) {                    Plotly.newPlot(                        "8d69f2ca-c50e-4d2e-afcc-89d512f5e94f",                        [{"x":["technique","statistical","evaluation","advantage","inversion","relations","likelihood","programming","algorithm","reinforcement","introduce","alternative","performing","characterizing","estimator","introduced","importance","illustrate","improvement","subsequently","demonstrate","techniques","distribution","performance","supervised","frequently","classification","prediction","necessarily","distributions","including","available","approximation","criterion","unsupervised","selection","probability","predictive","involving","empirical","empirically","marginalization","particular","quantitative","architectures","effective","separation","intrinsic","consistent","applications","properties","effectiveness","efficient","rendering","translation","representations","formation","integration","automatically","segmentation","convolutional","perceptual","foreground","illumination","intermediate","lambertian","underlying","parameters","challenging","qualitative","estimation","subjective","increased","algorithms","traditionally","correlation","reference","evaluated","constructed","outperforms","correlating","assessment","corresponding","cluttered","structural","different","consisting","shortcomings","summation","reconstruct","perceived","approaches","evaluating","developed","additionally","surveillance","benchmark","reconstructed","background","information","objective","construct","minimization","classical","regression","unbounded","generated","assumption","maximizes","inference","frequentist","explanation","generalization","generator","detection","correctness","improving","experimental","usefulness","demonstrating","experimentally","contributions","surrogates","proposing","viewpoint","minimizing","surrogate","functions","algorithmic","optimization","accelerated","iteratively","convergence","coordinate","incremental","typically","integrate","integrates","architecture","described","retrieval","baselines","importantly","representation","multimodal","multitask","heterogeneously","characterization","histograms","exposition","homogeneous","competitively","naturally","recognition","configuration","prototype","trainable","advancements","processing","extractors","automatic","realistically","personality","comparable","activities","supporting","embedding","essential","drastically","requirement","applicable","predicting","processes","dependencies","exchangeability","clustering","formulation","restaurant","traditional","dependent","partitions","sequential","connections","nonparametric","propagating","differences","according","activation","interpretability","significant","computing","describes","difference","important","contribution","advantages","submissions","translations","evaluations","orthographic"],"y":[258,177,264,103,6,89,57,146,814,125,330,103,75,16,26,122,93,71,137,33,574,409,219,934,189,34,518,228,19,120,254,301,102,51,139,141,166,62,50,150,79,4,276,73,133,276,26,40,65,439,202,205,415,15,111,241,23,50,189,212,368,21,23,45,27,3,114,227,262,48,206,27,34,603,19,83,42,132,61,276,4,47,124,10,77,761,40,11,3,35,9,453,58,208,48,31,200,24,72,709,151,76,67,108,126,9,155,48,9,243,1,19,98,34,348,20,105,388,29,38,52,43,4,23,29,47,12,190,43,289,21,35,119,30,28,104,38,19,245,74,112,70,16,335,25,8,2,30,5,0,19,4,66,369,31,17,28,9,307,10,194,5,5,96,34,24,113,69,11,34,48,76,115,48,0,135,75,6,158,74,14,80,57,16,7,63,97,36,24,251,119,86,69,368,73,80,6,20,52,6],"type":"bar"},{"x":["technique","statistical","e ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4595,), (4595, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Time</span> <span style=''>Hopping</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.32978723404255317);'>reinforcement</span> <span style=''>learning</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.4202898550724638);'>simulations</span> <br/><br/><span style=''>This</span> <span style=''>preprint</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>withdrawn</span> <span style=''>by</span> <span style=''>the</span> <span style=''>author</span> <span style=''>for</span> <span style=''>revision</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Variance</span> <span style=''>Aware</span> <span style=''>Regret</span> <span style=''>Bounds</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Undiscounted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforcement</span> <span style=''>Learning</span> <span style=''>in</span> <span style=''>MDPs</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>and</span> <span style=''>discrete</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style=''>Process</span> <span style=''>(MDP)</span> <span style=''>under</span> <span style=''>the</span> <span style=''>average</span> <span style=''>reward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>when</span> <span style=''>the</span> <span style=''>learner</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interacts</span> <span style=''>with</span> <span style=''>the</span> <span style=''>system</span> <span style=''>in</span> <span style=''>a</span> <span style=''>single</span> <span style=''>stream</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>starting</span> <span style=''>from</span> <span style=''>an</span> <span style=''>initial</span> <span style=''>state</span> <span style=''>without</span> <span style=''>any</span> <span style=''>reset</span> <span style=''>We</span> <span style=''>revisit</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>that</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>making</span> <span style=''>appear</span> <span style=''>the</span> <span style=''>local</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>bias</span> <span style=''>function</span> <span style=''>in</span> <span style=''>place</span> <span style=''>of</span> <span style=''>the</span> <span style=''>diameter</span> <span style=''>of</span> <span style=''>the</span> <span style=''>MDP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>KL</span> <span style=''>UCRL</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishing</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>scaling</span> <span style=''>as</span> <span style=''>widetilde</span> <span style=''>mathcal</span> <span style=''>OBigl(textstyle</span> <span style=''>sqrtSsum</span> <span style=''>sabf</span> <span style=''>Vstar</span> <span style=''>saTBig)</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>ergodic</span> <span style=''>MDPs</span> <span style=''>where</span> <span style=''>S</span> <span style=''>denotes</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>states</span> <span style=''>and</span> <span style=''>where</span> <span style=''>bf</span> <span style=''>Vstar</span> <span style=''>sa</span> <span style=''>is</span> <span style=''>the</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Testable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Implications</span> <span style=''>of</span> <span style=''>Causal</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Hidden</span> <span style='background-color:rgba(255, 0, 0, 0.40625);'>Variables</span> <br/><br/><span style=''>The</span> <span style=''>validity</span> <span style=''>OF</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>tested</span> <span style=''>ONLY</span> <span style=''>IF</span> <span style=''>the</span> <span style=''>model</span> <span style=''>imposes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>ON</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>governs</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>data</span> <span style=''>IN</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>OF</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>unmeasured</span> <span style='background-color:rgba(255, 0, 0, 0.40625);'>variables</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>may</span> <span style=''>impose</span> <span style=''>two</span> <span style=''>types</span> <span style=''>OF</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>independencies</span> <span style=''>AS</span> <span style=''>READ</span> <span style=''>through</span> <span style=''>the</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>AND</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>FOR</span> <span style=''>which</span> <span style=''>no</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>IS</span> <span style=''>availableThis</span> <span style=''>paper</span> <span style=''>offers</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.34426229508196726);'>systematic</span> <span style=''>way</span> <span style=''>OF</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>AND</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>facilitates</span> <span style=''>the</span> <span style=''>task</span> <span style=''>OF</span> <span style=''>testing</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>AS</span> <span style=''>well</span> <span style=''>AS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inferring</span> <span style=''>such</span> <span style=''>models</span> <span style=''>FROM</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>WMRB</span> <span style=''>Learning</span> <span style=''>to</span> <span style=''>Rank</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Scalable</span> <span style=''>Batch</span> <span style=''>Training</span> <span style=''>Approach</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>named</span> <span style=''>Weighted</span> <span style=''>Margin</span> <span style=''>Rank</span> <span style=''>Batch</span> <span style=''>loss</span> <span style=''>(WMRB)</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>Weighted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Rank</span> <span style=''>Pairwise</span> <span style=''>loss</span> <span style=''>(WARP)</span> <span style=''>WMRB</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>new</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>batch</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>allows</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>item</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilization</span> <span style=''>of</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerate</span> <span style=''>training</span> <span style=''>In</span> <span style=''>three</span> <span style=''>item</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendation</span> <span style=''>tasks</span> <span style=''>WMRB</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>WARP</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>baselines</span> <span style=''>Moreover</span> <span style=''>WMRB</span> <span style=''>shows</span> <span style=''>clear</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>as</span> <span style=''>data</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13847251962883655)
# 	architecture (0.08743754461099215)
# 	processing (0.10956459671663098)
# 	knowledge (0.1270521056388294)
# 	segmentation (0.07566024268379729)
# 	information (0.25303354746609563)
# 	detection (0.12419700214132762)
# 	convolutional (0.13133476088508209)
# 	different (0.2715917201998572)
# 	recognition (0.1316916488222698)
#
# Some Statistics words are:
# 	optimization (0.1891891891891892)
# 	theoretical (0.14914914914914915)
# 	variables (0.13513513513513514)
# 	statistical (0.16166166166166165)
# 	estimation (0.17417417417417416)
# 	distribution (0.1816816816816817)
# 	algorithm (0.4014014014014014)
# 	dimensional (0.18468468468468469)
# 	inference (0.20770770770770772)
# 	regression (0.18518518518518517)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="097dd05b-1831-4485-860e-702884c55e49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("097dd05b-1831-4485-860e-702884c55e49")) {                    Plotly.newPlot(                        "097dd05b-1831-4485-860e-702884c55e49",                        [{"x":["technique","statistical","evaluation","advantage","inversion","relations","likelihood","programming","algorithm","reinforcement","introduce","alternative","performing","characterizing","estimator","introduced","importance","illustrate","improvement","subsequently","demonstrate","techniques","distribution","performance","supervised","frequently","classification","prediction","necessarily","distributions","including","available","approximation","criterion","unsupervised","selection","probability","predictive","involving","empirical","empirically","marginalization","particular","quantitative","architectures","effective","separation","intrinsic","consistent","applications","properties","effectiveness","efficient","rendering","translation","representations","formation","integration","automatically","segmentation","convolutional","perceptual","foreground","illumination","intermediate","lambertian","underlying","parameters","challenging","qualitative","estimation","subjective","increased","algorithms","traditionally","correlation","reference","evaluated","constructed","outperforms","correlating","assessment","corresponding","cluttered","structural","different","consisting","shortcomings","summation","reconstruct","perceived","approaches","evaluating","developed","additionally","surveillance","benchmark","reconstructed","background","information","objective","construct","minimization","classical","regression","unbounded","generated","assumption","maximizes","inference","frequentist","explanation","generalization","generator","detection","correctness","improving","experimental","usefulness","demonstrating","experimentally","contributions","surrogates","proposing","viewpoint","minimizing","surrogate","functions","algorithmic","optimization","accelerated","iteratively","convergence","coordinate","incremental","typically","integrate","integrates","architecture","described","retrieval","baselines","importantly","representation","multimodal","multitask","heterogeneously","characterization","histograms","exposition","homogeneous","competitively","naturally","recognition","configuration","prototype","trainable","advancements","processing","extractors","automatic","realistically","personality","comparable","activities","supporting","embedding","essential","drastically","requirement","applicable","predicting","processes","dependencies","exchangeability","clustering","formulation","restaurant","traditional","dependent","partitions","sequential","connections","nonparametric","propagating","differences","according","activation","interpretability","significant","computing","describes","difference","important","contribution","advantages","submissions","translations","evaluations","orthographic","performed","comparing","annotated","arbitrary","structured","annotation","predicted","containing","hypothesized","transcription","consonants","framework","challenge","durations","replicable","measurement","expectations","perturbations","classifiers","interpolate","adversarial","satisfying","dimensional","estimates","generally","experiments","establish","boundaries","remarkably","theoretical","observations","curvature","relatively","constraints","dimension","generalizes","robustness","datapoints","vulnerable","nonlinear","exhibited","knowledge","deterministic","classifying","possibility","structure","increasing","automated","intervention","evolution","symmetries","validation","correctly","normality" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	exposition
# 	exchangeability
# 	replicable
# 	normality
# 	misspecified
# 	penalization
# 	comorbidity
# 	impactful
# 	reformulating
# 	divergent
# 	couplings
# 	radiographs
# 	inflation
# 	isometrically
# 	nonparanormal
# 	thermostats
# 	imaginary
# 	quadrature
# 	therapies
# 	observables
# Some words which never appear in Statistics papers:
# 	illumination
# 	lambertian
# 	extractors
# 	personality
# 	disjunctions
# 	interpreter
# 	syntactically
# 	formalisms
# 	sadrzadeh
# 	linguistics
# 	perfusion
# 	happiness
# 	semantically
# 	disregard
# 	paraphrase
# 	acquisitions
# 	cartesian
# 	plagiarism
# 	occlusions
# 	monocular

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.066073892380807e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
